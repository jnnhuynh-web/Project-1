# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import os
from config import key

csv = pd.read_csv('stations.csv')

# %%
version = 'v1'
package = ['history','stations']

city = 'Toronto'
country = 'Canada'

start_date_daily = '2007-01-01'
end_date_daily = '2019-01-01'

start_date_month = '2007-01'
end_date_month = '2018-12'

#station it is for Isachsen Meteorological Aeronautical Presentation System
station_id = '71074'

#url structure = https://api.meteostat.net/{VERSION}/{PACKAGE}/{METHOD}?{PARAMETERS}
#https://api.meteostat.net/v1/history/hourly?station=03772&start=2019-05-02&end=2019-05-11&time_zone=Europe/London&time_format=Y-m-d%20H:i&key=XXXXXXXX
#https://api.meteostat.net/v1/history/daily?station=10637&start=2017-01-01&end=2017-12-31&key=XXXXXXXX

historyparams_daily ={
    'start':start_date_daily,
    'end':end_date_daily,
    'key':key
    }

historyparams_monthly ={
    'start':start_date_month,
    'end':end_date_month,
    'key':key
    }

#method includes: daily, monthly
qry_daily_url = f'https://api.meteostat.net/v1/history/daily?station={station_id}'
qry_monthly_url = f'https://api.meteostat.net/v1/history/monthly?station={station_id}'

#get request for history
history_monthly = requests.get(qry_monthly_url,params=historyparams_monthly).json()
history_daily = requests.get(qry_daily_url,params=historyparams_daily).json()
history_monthly
# Out:
# {'meta': {'source': 'National Oceanic and Atmospheric Administration, Deutscher Wetterdienst'},
#  'data': [{'month': '2008-01',
#    'temperature_mean': -36.7,
#    'temperature_mean_min': -40,
#    'temperature_mean_max': -34,
#    'temperature_min': -46.1,
#    'temperature_max': -19,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-02',
#    'temperature_mean': -34.7,
#    'temperature_mean_min': -37.9,
#    'temperature_mean_max': -31.5,
#    'temperature_min': -44.4,
#    'temperature_max': -19.2,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-03',
#    'temperature_mean': -34.3,
#    'temperature_mean_min': -37.2,
#    'temperature_mean_max': -30.9,
#    'temperature_min': -43.3,
#    'temperature_max': -22.3,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-04',
#    'temperature_mean': -21.8,
#    'temperature_mean_min': -25,
#    'temperature_mean_max': -18.6,
#    'temperature_min': -30.8,
#    'temperature_max': -13.6,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-05',
#    'temperature_mean': -7.4,
#    'temperature_mean_min': -9.8,
#    'temperature_mean_max': -4.9,
#    'temperature_min': -23,
#    'temperature_max': 6.4,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-06',
#    'temperature_mean': 2.9,
#    'temperature_mean_min': 0.3,
#    'temperature_mean_max': 5.6,
#    'temperature_min': -6.2,
#    'temperature_max': 15.4,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-07',
#    'temperature_mean': 5.7,
#    'temperature_mean_min': 2.8,
#    'temperature_mean_max': 8.6,
#    'temperature_min': -1,
#    'temperature_max': 16.9,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-08',
#    'temperature_mean': 1.6,
#    'temperature_mean_min': -0.7,
#    'temperature_mean_max': 3.9,
#    'temperature_min': -5.9,
#    'temperature_max': 14.6,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-09',
#    'temperature_mean': -7.8,
#    'temperature_mean_min': -10,
#    'temperature_mean_max': -5.5,
#    'temperature_min': -18.1,
#    'temperature_max': -0.4,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-10',
#    'temperature_mean': -17.5,
#    'temperature_mean_min': -20.3,
#    'temperature_mean_max': -14,
#    'temperature_min': -29.4,
#    'temperature_max': -2.8,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-11',
#    'temperature_mean': -20.2,
#    'temperature_mean_min': -22.9,
#    'temperature_mean_max': -18,
#    'temperature_min': -28.6,
#    'temperature_max': -8,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2008-12',
#    'temperature_mean': -29.3,
#    'temperature_mean_min': -31.9,
#    'temperature_mean_max': -27.1,
#    'temperature_min': -37.4,
#    'temperature_max': -17.8,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2011-01',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2011-02',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2011-03',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2011-04',
#    'temperature_mean': -24.6,
#    'temperature_mean_min': -26.7,
#    'temperature_mean_max': -22.4,
#    'temperature_min': -35.9,
#    'temperature_max': -16.7,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2011-05',
#    'temperature_mean': -10.9,
#    'temperature_mean_min': -12.7,
#    'temperature_mean_max': -8.6,
#    'temperature_min': -24.5,
#    'temperature_max': -0.7,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1021.5,
#    'sunshine': None},
#   {'month': '2011-06',
#    'temperature_mean': 1.9,
#    'temperature_mean_min': -0.5,
#    'temperature_mean_max': 4.1,
#    'temperature_min': -9.5,
#    'temperature_max': 15.3,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1018.1,
#    'sunshine': None},
#   {'month': '2011-07',
#    'temperature_mean': 7.3,
#    'temperature_mean_min': 3.4,
#    'temperature_mean_max': 10.6,
#    'temperature_min': -0.2,
#    'temperature_max': 17.4,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1013.4,
#    'sunshine': None},
#   {'month': '2011-08',
#    'temperature_mean': 4.2,
#    'temperature_mean_min': 1.4,
#    'temperature_mean_max': 6.7,
#    'temperature_min': -5.5,
#    'temperature_max': 16.3,
#    'precipitation': 6,
#    'raindays': 2,
#    'pressure': 1016.5,
#    'sunshine': None},
#   {'month': '2011-09',
#    'temperature_mean': -8.2,
#    'temperature_mean_min': -11,
#    'temperature_mean_max': -4.8,
#    'temperature_min': -20.6,
#    'temperature_max': 1,
#    'precipitation': 8,
#    'raindays': 2,
#    'pressure': 1006.2,
#    'sunshine': None},
#   {'month': '2011-10',
#    'temperature_mean': -17.3,
#    'temperature_mean_min': -20.8,
#    'temperature_mean_max': -14.1,
#    'temperature_min': -31.5,
#    'temperature_max': -2.5,
#    'precipitation': 0,
#    'raindays': 0,
#    'pressure': 1013.7,
#    'sunshine': None},
#   {'month': '2011-11',
#    'temperature_mean': -24,
#    'temperature_mean_min': -26.6,
#    'temperature_mean_max': -21.5,
#    'temperature_min': -32,
#    'temperature_max': -11,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1010.1,
#    'sunshine': None},
#   {'month': '2011-12',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2012-01',
#    'temperature_mean': -31.4,
#    'temperature_mean_min': -33.7,
#    'temperature_mean_max': -29,
#    'temperature_min': -43.1,
#    'temperature_max': -18.8,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1009.8,
#    'sunshine': None},
#   {'month': '2012-02',
#    'temperature_mean': -33.7,
#    'temperature_mean_min': -36.7,
#    'temperature_mean_max': -31,
#    'temperature_min': -45.3,
#    'temperature_max': -19.5,
#    'precipitation': 37,
#    'raindays': 10,
#    'pressure': 1013.1,
#    'sunshine': None},
#   {'month': '2012-03',
#    'temperature_mean': -33.4,
#    'temperature_mean_min': -35.2,
#    'temperature_mean_max': -31.3,
#    'temperature_min': -42.6,
#    'temperature_max': -17.4,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1013.4,
#    'sunshine': None},
#   {'month': '2012-04',
#    'temperature_mean': -22.3,
#    'temperature_mean_min': -25.3,
#    'temperature_mean_max': -19.6,
#    'temperature_min': -35.3,
#    'temperature_max': -12.6,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1024.4,
#    'sunshine': None},
#   {'month': '2012-05',
#    'temperature_mean': -10.3,
#    'temperature_mean_min': -12.7,
#    'temperature_mean_max': -7.5,
#    'temperature_min': -22.8,
#    'temperature_max': -0.1,
#    'precipitation': 45,
#    'raindays': 19,
#    'pressure': 1021.8,
#    'sunshine': None},
#   {'month': '2012-06',
#    'temperature_mean': 3.1,
#    'temperature_mean_min': 0.8,
#    'temperature_mean_max': 5.2,
#    'temperature_min': -3.4,
#    'temperature_max': 15.8,
#    'precipitation': 36,
#    'raindays': 12,
#    'pressure': 1018.1,
#    'sunshine': None},
#   {'month': '2012-07',
#    'temperature_mean': 5.1,
#    'temperature_mean_min': 2,
#    'temperature_mean_max': 8.2,
#    'temperature_min': -0.7,
#    'temperature_max': 16.6,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1011.5,
#    'sunshine': None},
#   {'month': '2012-08',
#    'temperature_mean': 2.4,
#    'temperature_mean_min': 0.1,
#    'temperature_mean_max': 4.5,
#    'temperature_min': -4.1,
#    'temperature_max': 16,
#    'precipitation': 23,
#    'raindays': 6,
#    'pressure': 1008.4,
#    'sunshine': None},
#   {'month': '2012-09',
#    'temperature_mean': -3.8,
#    'temperature_mean_min': -6.2,
#    'temperature_mean_max': -1.3,
#    'temperature_min': -11.3,
#    'temperature_max': 1.7,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1008.5,
#    'sunshine': None},
#   {'month': '2012-10',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2012-11',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2012-12',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2013-01',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2013-02',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2013-03',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2013-04',
#    'temperature_mean': -20.4,
#    'temperature_mean_min': -22.1,
#    'temperature_mean_max': -16.5,
#    'temperature_min': -27.3,
#    'temperature_max': -10.5,
#    'precipitation': 18,
#    'raindays': 4,
#    'pressure': 1013.1,
#    'sunshine': None},
#   {'month': '2013-05',
#    'temperature_mean': -12,
#    'temperature_mean_min': -14,
#    'temperature_mean_max': -10.5,
#    'temperature_min': -23.2,
#    'temperature_max': -2.6,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1019.2,
#    'sunshine': None},
#   {'month': '2013-06',
#    'temperature_mean': -3.1,
#    'temperature_mean_min': -4.1,
#    'temperature_mean_max': -1.7,
#    'temperature_min': -11,
#    'temperature_max': 0.7,
#    'precipitation': 5,
#    'raindays': 1,
#    'pressure': 1009.6,
#    'sunshine': None},
#   {'month': '2013-07',
#    'temperature_mean': 1.9,
#    'temperature_mean_min': -0.3,
#    'temperature_mean_max': 4,
#    'temperature_min': -3.7,
#    'temperature_max': 10.5,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1010.5,
#    'sunshine': None},
#   {'month': '2013-08',
#    'temperature_mean': -2.1,
#    'temperature_mean_min': -4.1,
#    'temperature_mean_max': 0,
#    'temperature_min': -9.4,
#    'temperature_max': 5.8,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1007.6,
#    'sunshine': None},
#   {'month': '2013-09',
#    'temperature_mean': None,
#    'temperature_mean_min': -9.6,
#    'temperature_mean_max': -5,
#    'temperature_min': -17.5,
#    'temperature_max': -1.5,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2013-10',
#    'temperature_mean': -18.3,
#    'temperature_mean_min': -22.8,
#    'temperature_mean_max': -14.3,
#    'temperature_min': -34.7,
#    'temperature_max': -4.9,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1014.1,
#    'sunshine': None},
#   {'month': '2013-11',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2013-12',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2014-01',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2014-02',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2014-03',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2014-04',
#    'temperature_mean': -24.6,
#    'temperature_mean_min': -27.5,
#    'temperature_mean_max': -21.6,
#    'temperature_min': -35.5,
#    'temperature_max': -11.1,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1019.2,
#    'sunshine': None},
#   {'month': '2014-05',
#    'temperature_mean': -10,
#    'temperature_mean_min': -12.3,
#    'temperature_mean_max': -7.7,
#    'temperature_min': -21.6,
#    'temperature_max': -0.9,
#    'precipitation': 74,
#    'raindays': 10,
#    'pressure': 1016.1,
#    'sunshine': None},
#   {'month': '2014-06',
#    'temperature_mean': -3.3,
#    'temperature_mean_min': -4.9,
#    'temperature_mean_max': -2,
#    'temperature_min': -9.9,
#    'temperature_max': 1.1,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1017.6,
#    'sunshine': None},
#   {'month': '2014-07',
#    'temperature_mean': 1.1,
#    'temperature_mean_min': -1,
#    'temperature_mean_max': 3,
#    'temperature_min': -4.7,
#    'temperature_max': 8.4,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1011.4,
#    'sunshine': None},
#   {'month': '2014-08',
#    'temperature_mean': 0.8,
#    'temperature_mean_min': -1,
#    'temperature_mean_max': 2.8,
#    'temperature_min': -3.7,
#    'temperature_max': 8.8,
#    'precipitation': 27,
#    'raindays': 10,
#    'pressure': 1011.2,
#    'sunshine': None},
#   {'month': '2014-09',
#    'temperature_mean': -6.7,
#    'temperature_mean_min': -9,
#    'temperature_mean_max': -4.2,
#    'temperature_min': -20.6,
#    'temperature_max': 4.7,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1009.8,
#    'sunshine': None},
#   {'month': '2014-10',
#    'temperature_mean': -17.8,
#    'temperature_mean_min': -20.4,
#    'temperature_mean_max': -15.4,
#    'temperature_min': -27.9,
#    'temperature_max': -5.4,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1021.6,
#    'sunshine': None},
#   {'month': '2014-11',
#    'temperature_mean': -23.9,
#    'temperature_mean_min': -27.2,
#    'temperature_mean_max': -20.5,
#    'temperature_min': -32,
#    'temperature_max': -8.5,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1011.4,
#    'sunshine': None},
#   {'month': '2014-12',
#    'temperature_mean': -32.1,
#    'temperature_mean_min': -35.2,
#    'temperature_mean_max': -29.1,
#    'temperature_min': -40.1,
#    'temperature_max': -14.9,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1015.6,
#    'sunshine': None},
#   {'month': '2015-01',
#    'temperature_mean': None,
#    'temperature_mean_min': -32.1,
#    'temperature_mean_max': -27.6,
#    'temperature_min': -39.6,
#    'temperature_max': -16.2,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2015-02',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2015-03',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2015-04',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2015-05',
#    'temperature_mean': -11.2,
#    'temperature_mean_min': -13.9,
#    'temperature_mean_max': -8.6,
#    'temperature_min': -19.8,
#    'temperature_max': -0.9,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1018.2,
#    'sunshine': None},
#   {'month': '2015-06',
#    'temperature_mean': 1.7,
#    'temperature_mean_min': -0.3,
#    'temperature_mean_max': 3.8,
#    'temperature_min': -6.3,
#    'temperature_max': 10.3,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1013.5,
#    'sunshine': None},
#   {'month': '2015-07',
#    'temperature_mean': 7.6,
#    'temperature_mean_min': 4.4,
#    'temperature_mean_max': 10.7,
#    'temperature_min': -1.2,
#    'temperature_max': 17.4,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1018.2,
#    'sunshine': None},
#   {'month': '2015-08',
#    'temperature_mean': 2.1,
#    'temperature_mean_min': -0.2,
#    'temperature_mean_max': 4.4,
#    'temperature_min': -2.8,
#    'temperature_max': 11.1,
#    'precipitation': 12,
#    'raindays': 4,
#    'pressure': 1013.9,
#    'sunshine': None},
#   {'month': '2015-09',
#    'temperature_mean': -5.9,
#    'temperature_mean_min': -8.2,
#    'temperature_mean_max': -3.6,
#    'temperature_min': -18.4,
#    'temperature_max': 4.6,
#    'precipitation': 13,
#    'raindays': 4,
#    'pressure': 1011.4,
#    'sunshine': None},
#   {'month': '2015-10',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2015-11',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2015-12',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2016-01',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2016-02',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2016-03',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2016-04',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2016-05',
#    'temperature_mean': -8.3,
#    'temperature_mean_min': -10,
#    'temperature_mean_max': -6.4,
#    'temperature_min': -17.8,
#    'temperature_max': -1.8,
#    'precipitation': 51,
#    'raindays': 6,
#    'pressure': 1018.7,
#    'sunshine': None},
#   {'month': '2016-06',
#    'temperature_mean': 0.4,
#    'temperature_mean_min': -1,
#    'temperature_mean_max': 1.9,
#    'temperature_min': -8.5,
#    'temperature_max': 5.9,
#    'precipitation': 32,
#    'raindays': 8,
#    'pressure': 1008.8,
#    'sunshine': None},
#   {'month': '2016-07',
#    'temperature_mean': 7.2,
#    'temperature_mean_min': 4.5,
#    'temperature_mean_max': 9.8,
#    'temperature_min': -0.4,
#    'temperature_max': 15.2,
#    'precipitation': 26,
#    'raindays': 5,
#    'pressure': 1012.7,
#    'sunshine': None},
#   {'month': '2016-08',
#    'temperature_mean': 0.2,
#    'temperature_mean_min': -1.3,
#    'temperature_mean_max': 1.7,
#    'temperature_min': -5.3,
#    'temperature_max': 8.1,
#    'precipitation': 11,
#    'raindays': 3,
#    'pressure': 1011.8,
#    'sunshine': None},
#   {'month': '2016-09',
#    'temperature_mean': -5.4,
#    'temperature_mean_min': -7.6,
#    'temperature_mean_max': -3.1,
#    'temperature_min': -15.3,
#    'temperature_max': 0.8,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 998.6,
#    'sunshine': None},
#   {'month': '2016-10',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': -8.4,
#    'temperature_min': -20.4,
#    'temperature_max': -2,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1010,
#    'sunshine': None},
#   {'month': '2016-11',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2016-12',
#    'temperature_mean': -27.6,
#    'temperature_mean_min': -31.1,
#    'temperature_mean_max': -23.9,
#    'temperature_min': -38.9,
#    'temperature_max': -7.7,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1014.8,
#    'sunshine': None},
#   {'month': '2018-01',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2018-02',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2018-03',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2018-04',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2018-05',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2018-06',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2018-07',
#    'temperature_mean': 1.4,
#    'temperature_mean_min': -0.5,
#    'temperature_mean_max': 3,
#    'temperature_min': -2.5,
#    'temperature_max': 8.9,
#    'precipitation': 19,
#    'raindays': 7,
#    'pressure': 1002.7,
#    'sunshine': None},
#   {'month': '2018-08',
#    'temperature_mean': 1.4,
#    'temperature_mean_min': -0.1,
#    'temperature_mean_max': 3,
#    'temperature_min': -5,
#    'temperature_max': 9.1,
#    'precipitation': 14,
#    'raindays': 5,
#    'pressure': 1003,
#    'sunshine': None},
#   {'month': '2018-09',
#    'temperature_mean': -7.9,
#    'temperature_mean_min': -9.8,
#    'temperature_mean_max': -5.5,
#    'temperature_min': -16.1,
#    'temperature_max': 1.3,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': 1010.6,
#    'sunshine': None},
#   {'month': '2018-10',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2018-11',
#    'temperature_mean': None,
#    'temperature_mean_min': None,
#    'temperature_mean_max': None,
#    'temperature_min': None,
#    'temperature_max': None,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None},
#   {'month': '2018-12',
#    'temperature_mean': -30,
#    'temperature_mean_min': -32.1,
#    'temperature_mean_max': -27.4,
#    'temperature_min': -36.5,
#    'temperature_max': -17.2,
#    'precipitation': None,
#    'raindays': None,
#    'pressure': None,
#    'sunshine': None}]}

# %%
#THIS IS FOR MONTHLY
date_monthly = history_monthly['data'][0]['month']
temp_mean_monthly = history_monthly['data'][0]['temperature_mean']
temp_mean_min_monthly = history_monthly['data'][0]['temperature_mean_min']
temp_mean_max_monthly = history_monthly['data'][0]['temperature_mean_max']
temp_min_monthly = history_monthly['data'][0]['temperature_min']
temp_max_monthly = history_monthly['data'][0]['temperature_max']
precipitation_monthly = history_monthly['data'][0]['precipitation']
raindays_monthly = history_monthly['data'][0]['raindays']
pressure_monthly = history_monthly['data'][0]['pressure']
sunshine_monthly = history_monthly['data'][0]['sunshine']

# THIS IS FOR DAILY
date_daily = history_daily['data'][0]['date']
temp_daily = history_daily['data'][0]['temperature']
temp_min_daily = history_daily['data'][0]['temperature_min']
temp_max_daily = history_daily['data'][0]['temperature_max']
precip_daily = history_daily['data'][0]['precipitation']
snowfall_daily = history_daily['data'][0]['snowfall']
snowdepth_daily = history_daily['data'][0]['snowdepth']
wind_dir_daily = history_daily['data'][0]['winddirection']
wind_speed_daily = history_daily['data'][0]['windspeed']
peakgust_daily = history_daily['data'][0]['peakgust']
sunshine_daily = history_daily['data'][0]['sunshine']
pressure_daily = history_daily['data'][0]['pressure']

# %%
date_ls = []
temp_mean_ls = []
temp_mean_min_ls = []
temp_mean_max_ls = []
temp_min_ls = []
temp_max_ls = []
precipitation_ls = []
raindays_ls = []
pressure_ls = []
sunshine_ls = []

for x in range(len(history_monthly["data"])):
    date_ls.append(history_monthly['data'][x]['month'])
    temp_mean_ls.append(history_monthly['data'][x]['temperature_mean'])
    temp_mean_min_ls.append(history_monthly['data'][x]['temperature_mean_max'])
    temp_mean_max_ls.append(history_monthly['data'][x]['temperature_mean_min'])
    temp_min_ls.append(history_monthly['data'][x]['temperature_min'])
    temp_max_ls.append(history_monthly['data'][x]['temperature_max'])
    precipitation_ls.append(history_monthly['data'][x]['precipitation'])
    raindays_ls.append(history_monthly['data'][x]['raindays'])
    pressure_ls.append(history_monthly['data'][x]['pressure'])
    sunshine_ls.append(history_monthly['data'][x]['sunshine'])
    
print(f"{len(date_ls)},{len(temp_mean_ls)},{len(temp_mean_ls)},{len(temp_mean_min_ls)},{len(temp_mean_max_ls)},{len(temp_min_ls)},{len(temp_max_ls)},{len(precipitation_ls)},{len(raindays_ls)},{len(pressure_ls)},{len(sunshine_ls)}")
# Out:
# 96,96,96,96,96,96,96,96,96,96,96

# %%
df = pd.DataFrame(date_ls).replace({"none":"0"}).rename(columns={"0":"date"})
df['tempMean'] = temp_mean_ls
df['tempMeanMin'] = temp_mean_min_ls
df['tempMeanMax'] =temp_mean_max_ls
df['tempMin'] =temp_min_ls
df['tempMax'] = temp_max_ls
df['precip'] = precipitation_ls
df['rainDays'] = raindays_ls
df['pressure'] = pressure_ls
df['sunshine'] = sunshine_ls
    
df.head()
# Out:
#          0  tempMean  tempMeanMin  tempMeanMax  tempMin  tempMax  precip  \
# 0  2008-01     -36.7        -34.0        -40.0    -46.1    -19.0     NaN
# 1  2008-02     -34.7        -31.5        -37.9    -44.4    -19.2     NaN
# 2  2008-03     -34.3        -30.9        -37.2    -43.3    -22.3     NaN
# 3  2008-04     -21.8        -18.6        -25.0    -30.8    -13.6     NaN
# 4  2008-05      -7.4         -4.9         -9.8    -23.0      6.4     NaN
#
#    rainDays  pressure sunshine
# 0       NaN       NaN     None
# 1       NaN       NaN     None
# 2       NaN       NaN     None
# 3       NaN       NaN     None
# 4       NaN       NaN     None

# %%
df.describe()
# Out:
#         tempMean  tempMeanMin  tempMeanMax    tempMin    tempMax     precip  \
# count  59.000000    62.000000    61.000000  62.000000  62.000000  19.000000
# mean  -10.850847    -8.598387   -13.570492 -20.324194  -0.361290  24.052632
# std    13.340829    13.030173    13.546271  14.418916  11.692822  18.518680
# min   -36.700000   -34.000000   -40.000000 -46.100000 -22.300000   0.000000
# 25%   -22.050000   -19.350000   -25.300000 -32.000000 -10.000000  11.500000
# 50%    -7.900000    -5.500000   -10.000000 -20.100000  -0.250000  19.000000
# 75%     1.400000     3.000000    -0.700000  -5.975000   8.875000  34.000000
# max     7.600000    10.700000     4.500000  -0.200000  17.400000  74.000000
#
#         rainDays     pressure
# count  19.000000    46.000000
# mean    6.210526  1013.117391
# std     4.553130     5.267566
# min     0.000000   998.600000
# 25%     3.500000  1010.025000
# 50%     5.000000  1013.100000
# 75%     9.000000  1017.325000
# max    19.000000  1024.400000

# %%
# GOOD CODE ENDS HERE

# %%
#ROUGH CODE FOLLOWS

# %%
cityparams ={
    'q':city,
    'key':key
    }

qry_url_city = 'https://api.meteostat.net/v1/stations/search?'

countryparams={
    'country':country,
    'key':key   
    }
#response_country = requests.get(qry_url_country).json()
qry_url_country = 'https://api.meteostat.net/v1/stations/search?q=CA'

#response_country = requests.get(qry_url_country).json()
test_url = f'https://api.meteostat.net/v1/stations/search?q={city}&key={key}'

# %%
#for index, row in staging_df.iterrows():
#    stationid = row['station_id']
#    stationidparams={
#    'start':start_date,
#    'end':end_date,
#    'key':key
#    }
#    print(f'Processing Record {index} set of | {stationid}')
#    response = requests.get(qry_history_url,params=stationidparams).json()
    
    #try:
    #    staging_df['meta_source'] = history['meta']['source']
    #except:KeyError
    #    print('missing values, i am going to skip it')
    #    print('====================================')

# %%
csv.head()
# Out:
#   stationid country       stationname        B         C     D     E       F  \
# 0     PABL0      US  Buckland Airport  65.9667 -161.1500   7.0  PABL     NaN
# 1      1001      NO         Jan Mayen  70.9333   -8.6667  10.0  ENJA  1001.0
# 2      1002      NO          Grahuken  79.7833   14.4667   NaN   NaN  1002.0
# 3      1003      NO          Hornsund  77.0000   15.5000  10.0   NaN  1003.0
# 4      1004      NO     Ny-Alesund Ii  78.9167   11.9333   8.0  ENAS  1004.0
#
#      G            H
# 0  BKC          NaN
# 1  NaN  Europe/Oslo
# 2  NaN  Europe/Oslo
# 3  NaN  Europe/Oslo
# 4  NaN  Europe/Oslo

# %%
# #station id
# station_df = csv['stationid']

# #reset index for dataframe
# station_df = station_df.reset_index()

# station_df.head()
# Out:
#    index stationid
# 0      0     PABL0
# 1      1      1001
# 2      2      1002
# 3      3      1003
# 4      4      1004

# %%
#stationid = row['stationid']

#station

stationidparams={
    'start':start_date,
    'end':end_date,
    'key':key
    }
    #print(f'Processing Record {index} set of | {stationid}')
response = requests.get(qry_history_url,params=stationidparams).json()

# %%
stationid = station_df['stationid']

# %%
station_df['stationid']

# %%
#city_df.loc[index,'Cloudiness']=response['clouds']['all']

for index, row in staging_df.iterrows():
    try:
        station_id = row['stationid']
        print(station_id)
    except:
        print('Type error, i am going to skip it')
        print('==================================')
    #qry_url = f'https://api.meteostat.net/v1/history/daily?station={station_id}'
    #stationidparams={
    #'start':start_date,
    #'end':end_date,
    #'key':key
    #}
    #print(f'Processing Record {index} set of | {station_id}')
    #response = requests.get(qry_url,params=stationidparams).json()
    #staging_df.loc[index,'meta_source'] = response['meta']['source']
    #except:KeyError
    #try:
        
        #print('missing values, i am going to skip it')
        #print('====================================')

# %%
station_id
