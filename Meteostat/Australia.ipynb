# %%
#IDCJAC0002_033106_Data1

import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../Reference/Australia/IDCJAC0002_033106/IDCJAC0002_033106_Data1.csv')

# %%
data.head(20)
# Out:
#    Product code  Bureau of Meteorology station number  Year  Month  \
# 0    IDCJAC0002                                 33106  2002      3
# 1    IDCJAC0002                                 33106  2002      4
# 2    IDCJAC0002                                 33106  2002      5
# 3    IDCJAC0002                                 33106  2002      6
# 4    IDCJAC0002                                 33106  2002      7
# 5    IDCJAC0002                                 33106  2002      8
# 6    IDCJAC0002                                 33106  2002      9
# 7    IDCJAC0002                                 33106  2002     10
# 8    IDCJAC0002                                 33106  2002     11
# 9    IDCJAC0002                                 33106  2002     12
# 10   IDCJAC0002                                 33106  2003      1
# 11   IDCJAC0002                                 33106  2003      2
# 12   IDCJAC0002                                 33106  2003      3
# 13   IDCJAC0002                                 33106  2003      4
# 14   IDCJAC0002                                 33106  2003      5
# 15   IDCJAC0002                                 33106  2003      6
# 16   IDCJAC0002                                 33106  2003      7
# 17   IDCJAC0002                                 33106  2003      8
# 18   IDCJAC0002                                 33106  2003      9
# 19   IDCJAC0002                                 33106  2003     10
#
#     Mean maximum temperature (°C) Quality
# 0                            29.0       Y
# 1                            27.1       Y
# 2                            24.8       Y
# 3                            22.0       Y
# 4                            21.6       Y
# 5                            22.6       Y
# 6                            25.9       Y
# 7                            27.6       Y
# 8                            27.9       Y
# 9                            30.0       Y
# 10                           29.6       Y
# 11                           29.5       Y
# 12                           28.3       Y
# 13                           27.3       Y
# 14                           24.3       Y
# 15                           22.7       Y
# 16                           21.8       Y
# 17                           23.5       Y
# 18                           26.2       Y
# 19                           28.3       Y

# %%
data = data.rename(columns={'Mean maximum temperature (°C)':'Mean Max Temp (C)'})

# %%
groupdf = data.groupby(by='Year').mean()

# %%
groupdf
# Out:
#       Bureau of Meteorology station number  Month  Mean Max Temp (C)
# Year
# 2002                               33106.0    7.5          25.850000
# 2003                               33106.0    6.5          26.758333
# 2004                               33106.0    6.5          27.016667
# 2005                               33106.0    6.5          26.925000
# 2006                               33106.0    6.5          26.058333
# 2007                               33106.0    6.5          25.925000
# 2008                               33106.0    6.5          25.991667
# 2009                               33106.0    6.5          26.500000
# 2010                               33106.0    6.5          26.175000
# 2011                               33106.0    6.5          25.608333
# 2012                               33106.0    6.5          25.883333
# 2013                               33106.0    6.5          26.608333
# 2014                               33106.0    6.5          26.291667
# 2015                               33106.0    6.5          26.741667
# 2016                               33106.0    6.5          27.158333
# 2017                               33106.0    6.5          26.883333
# 2018                               33106.0    6.5          26.558333
# 2019                               33106.0    5.0          25.344444

# %%
type(groupdf)
# Out:
# pandas.core.frame.DataFrame

# %%
del groupdf['Bureau of Meteorology station number']

# %%
del groupdf['Month']

# %%
australiadf = groupdf

# %%
australiadf
# Out:
#       Mean Max Temp (C)
# Year
# 2002          25.850000
# 2003          26.758333
# 2004          27.016667
# 2005          26.925000
# 2006          26.058333
# 2007          25.925000
# 2008          25.991667
# 2009          26.500000
# 2010          26.175000
# 2011          25.608333
# 2012          25.883333
# 2013          26.608333
# 2014          26.291667
# 2015          26.741667
# 2016          27.158333
# 2017          26.883333
# 2018          26.558333
# 2019          25.344444

# %%
australiadf.to_csv(r'Australia_meanMaxtemp_2002_2019.csv')

# %%
australiadf = australiadf.reset_index()

# %%
#find the years

# %%
x_axis = australiadf['Year']
y_axis = australiadf['Mean Max Temp (C)']

# %%
australiadf
# Out:
#     Year  Mean Max Temp (C)
# 0   2002          25.850000
# 1   2003          26.758333
# 2   2004          27.016667
# 3   2005          26.925000
# 4   2006          26.058333
# 5   2007          25.925000
# 6   2008          25.991667
# 7   2009          26.500000
# 8   2010          26.175000
# 9   2011          25.608333
# 10  2012          25.883333
# 11  2013          26.608333
# 12  2014          26.291667
# 13  2015          26.741667
# 14  2016          27.158333
# 15  2017          26.883333
# 16  2018          26.558333
# 17  2019          25.344444

# %%
fig,ax = plt.subplots()
ax.plot(x_axis,y_axis)

# %%
#groupdf = pd.DataFrame(groupdf)

# %%
#df2 = groupdf.agg('mean',axis='columns')
