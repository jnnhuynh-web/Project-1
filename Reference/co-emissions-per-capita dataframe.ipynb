# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
per_capita_load = "co-emissions-per-capita.csv"
yearly_cumulative_load = "cumulative-co-emissions.csv"

# Read the per capita and cumulative data files
per_capita_data = pd.read_csv(per_capita_load, encoding = "ISO_8859_1")
yearly_cumulative_data = pd.read_csv(yearly_cumulative_load, encoding = "ISO_8859_1")

# %%
# Cleaning the per capita data file
per_capita_data_clean = per_capita_data.replace(0, np.nan)
per_capita_data_clean1 = per_capita_data_clean.dropna(how='any')
per_capita_data_clean1
# Out:
#             Entity Code  Year  Per capita CO2 emissions (tonnes per capita)
# 149    Afghanistan  AFG  1949                                       0.001912
# 150    Afghanistan  AFG  1950                                       0.010871
# 151    Afghanistan  AFG  1951                                       0.011684
# 152    Afghanistan  AFG  1952                                       0.011544
# 153    Afghanistan  AFG  1953                                       0.013218
# 154    Afghanistan  AFG  1954                                       0.013037
# 155    Afghanistan  AFG  1955                                       0.018607
# 156    Afghanistan  AFG  1956                                       0.021812
# 157    Afghanistan  AFG  1957                                       0.034340
# 158    Afghanistan  AFG  1958                                       0.037987
# 159    Afghanistan  AFG  1959                                       0.043531
# ...

# %%
yearly_cumulative_data_clean = yearly_cumulative_data.replace(0, np.nan)
yearly_cumulative_data_clean1 = yearly_cumulative_data_clean.dropna(how='any')
yearly_cumulative_data_clean1
# Out:
#             Entity Code  Year  Cumulative CO2 emissions by nation (tonnes)
# 198    Afghanistan  AFG  1949                                       14656.0
# 199    Afghanistan  AFG  1950                                       98928.0
# 200    Afghanistan  AFG  1951                                      190528.0
# 201    Afghanistan  AFG  1952                                      282128.0
# 202    Afghanistan  AFG  1953                                      388384.0
# 203    Afghanistan  AFG  1954                                      494640.0
# 204    Afghanistan  AFG  1955                                      648528.0
# 205    Afghanistan  AFG  1956                                      831728.0
# 206    Afghanistan  AFG  1957                                     1124848.0
# 207    Afghanistan  AFG  1958                                     1454608.0
# 208    Afghanistan  AFG  1959                                     1839179.0
# ...

# %%
for i, eachrow in enumerate yearly_cumulative_data_clean1







#     total_month = 0
#     total_sum = 0
#     #list the revenue, dates, and list for revenue storage
#     revenue = []
#     date = []
#     rev_change = []
#     #loop through the rows for the sum and month
#     for i, eachrow in enumerate(filehandle):
#         total_month += 1
#         total_sum += int(eachrow[1])
#         revenue.append(eachrow[1])
#         date.append(eachrow[0])
#         if i>=1:
#             rev_change.append(int(revenue[i]) - int(revenue[i-1]))

# %%
# Cleaning the per cumulative data file
yearly_cumulative_df = yearly_cumulative_data.loc[:,["Entity","Code","Year","Cumulative CO2 emissions by nation (tonnes)"]]
yearly_cumulative_df.head()
# Out:
#         Entity Code  Year  Cumulative CO2 emissions by nation (tonnes)
# 0  Afghanistan  AFG  1751                                          NaN
# 1  Afghanistan  AFG  1752                                          NaN
# 2  Afghanistan  AFG  1753                                          NaN
# 3  Afghanistan  AFG  1754                                          NaN
# 4  Afghanistan  AFG  1755                                          NaN

# %%
per_capita_df.describe()
# Out:
#                Year  Per capita CO2 emissions (tonnes)
# count  42844.000000                                0.0
# mean    1908.625712                                NaN
# std       62.931926                                NaN
# min     1751.000000                                NaN
# 25%     1854.000000                                NaN
# 50%     1909.000000                                NaN
# 75%     1963.000000                                NaN
# max     2017.000000                                NaN

# %%
yearly_cumulative_df.describe()
# Out:
#                Year  Cumulative CO2 emissions by nation (tonnes)
# count  61677.000000                                          0.0
# mean    1884.000000                                          NaN
# std       77.076345                                          NaN
# min     1751.000000                                          NaN
# 25%     1817.000000                                          NaN
# 50%     1884.000000                                          NaN
# 75%     1951.000000                                          NaN
# max     2017.000000                                          NaN

# %%
per_capita_df.dtypes
# Out:
# Entity                                object
# Code                                  object
# Year                                   int64
# Per capita CO2 emissions (tonnes)    float64
# dtype: object
